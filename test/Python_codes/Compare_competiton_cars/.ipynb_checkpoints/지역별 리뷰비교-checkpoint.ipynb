# %%
import pandas as pd
import urllib.request, json
import numpy as np
import os
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import nltk, gensim
from nltk import word_tokenize
from tqdm import tqdm
# Out:
# C:\Users\kb910\Anaconda3\lib\site-packages\gensim\utils.py:865: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %% [markdown]
# # 데이터 불러오기 모든 SUV 컴플레인 데이터

# %%
os.chdir('C:\\Users\\kb910\\Google 드라이브\\경배끄10\\인턴\\csv파일\\\complain')
data = open('final_suv_compalin_us.json').read()
data = pd.DataFrame(json.loads(data))
print(data.shape)
data.head(5)
# Out:
# (28236, 12)
#                B_category         S_category   city country    date  \
# 0     seat_belts_air_bags           air_bags  Creek     USA  Sep 12
# 1                  lights  exterior_lighting     OH     USA  Apr 03
# 10               steering           steering     KS     USA  Apr 06
# 100   seat_belts_air_bags           air_bags     TN     USA  Aug 31
# 1000               engine             engine     MI     USA  Apr 28
#
#        make_name      model_name  model_year     sub_title  \
# 0     Volkswagen         Touareg      2012.0  30,000 miles
# 1     Volkswagen         Touareg      2012.0         miles
# 10    Volkswagen         Touareg      2012.0         miles
# 100    Chevrolet           Tahoe      2012.0         miles
# 1000        Jeep  Grand_Cherokee      2012.0         miles
#
#                                                    text           title  year
# 0     While traveling on highway 24 airbag spontaneo...         Touareg  2016
# 1     Car following me light issue. Lights on low be...         Touareg  2015
# 10    Steering wheel shakes during high way driving....         Touareg  2016
# 100   2 cracks around front passenger side airbag da...           Tahoe  2016
# 1000  Unexpected stall while driving. Happened twice...  Grand Cherokee  2016

# %%
data['model_name'].unique()
# Out:
# array(['Touareg', 'Tahoe', 'Grand_Cherokee', 'Sorento', 'Santa_Fe',
#        'Patriot', 'X-Trail', 'Rogue', 'CR-V', 'Wrangler', 'FJ_Cruiser',
#        'Compass', 'RAV4', 'Yukon', 'X5', 'Equinox', 'Escape', 'Forester',
#        'Terrain', 'Tucson', 'Q7', 'CX-5', 'XC90', 'X6', 'X1', 'Tiguan',
#        'Escalade', 'Sportage', 'Encore', 'Cayenne', 'Juke', 'Crosstour',
#        'Trax', 'MDX', 'Durango', 'Xterra', 'Suburban', 'Sequoia',
#        'Navigator', 'Expedition', 'Pathfinder', 'Murano', 'Armada', 'RDX',
#        'Pilot', 'Traverse', 'Venza', 'Outlander', 'Highlander', 'MKX',
#        'Flex', 'Explorer', 'Edge', 'Acadia', 'Enclave', 'XC60', 'CX-9',
#        'SRX', 'X3', 'Q5', 'Cherokee', 'Escalade_ESV', 'Land_Cruiser', 'X4',
#        'Macan', 'MKC', 'Q3', 'Renegade', 'Model_X', 'Envision', 'CX-3',
#        '500X', 'XT5', 'F-PACE'], dtype=object)

# %% [markdown]
# ##  텍스트를 주별로 나누기

# %%
len(data)
# Out:
# 28236

# %%
data = data[data['country']=='USA']
print("전체 USA 컴프레인 데이터 개수 :" + str(len(data)))
print("구별되지 않는 데이터 개수 :" +str(len(data['city'].unique())))

data.index = [x for x in range(len(data))]
# 구별되지 않는 데이터 약 3700개 제외
# Out:
# 전체 USA 컴프레인 데이터 개수 :24951
# 구별되지 않는 데이터 개수 :3751

# %%
inner = ['IL','SD','MI','MO','OH','WI','IN','MN','KS','ND','NE','IA']
west = ['CA','AZ','CO','UT','WA','NV','WY','OR','ID','MT','NM']
east = ['RI','ME','VT','DE','CT','MA','NJ','NH','MD','PA','VA','NY']
south = ['AR','LA','NC','MS','KY','AL','GA','WV','OK','FL','TN','SC','TX']

# %%
for index in tqdm(data.index.values):
    if (data['city'][index] in inner ):
        data.loc[index, 'City_category'] = 'Central'
    elif (data['city'][index] in west ):
        data.loc[index, 'City_category'] = 'West'
    elif (data['city'][index] in east ):
        data.loc[index, 'City_category'] = 'East'
    elif (data['city'][index] in south ):
        data.loc[index, 'City_category'] = 'South'
    else:
        data.loc[index, 'City_category'] = 0
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 24951/24951 [00:30<00:00, 824.28it/s]

# %%
real_data = data[data['City_category'] != 0]
print(real_data.shape)
real_data.head(5)

# 최종 지역 complain data 14,370개
# Out:
# (14370, 13)
#             B_category         S_category city country    date   make_name  \
# 1               lights  exterior_lighting   OH     USA  Apr 03  Volkswagen
# 2             steering           steering   KS     USA  Apr 06  Volkswagen
# 3  seat_belts_air_bags           air_bags   TN     USA  Aug 31   Chevrolet
# 4               engine             engine   MI     USA  Apr 28        Jeep
# 7          wheels_hubs             wheels   IL     USA  Nov 07         Kia
#
#        model_name  model_year  sub_title  \
# 1         Touareg      2012.0      miles
# 2         Touareg      2012.0      miles
# 3           Tahoe      2012.0      miles
# 4  Grand_Cherokee      2012.0      miles
# 7         Sorento      2013.0  982 miles
#
#                                                 text           title  year  \
# 1  Car following me light issue. Lights on low be...         Touareg  2015
# 2  Steering wheel shakes during high way driving....         Touareg  2016
# 3  2 cracks around front passenger side airbag da...           Tahoe  2016
# 4  Unexpected stall while driving. Happened twice...  Grand Cherokee  2016
# 7  While drive at slow speeds of about 5 to 10 mp...   Sorento 4-cyl  2012
#
#   City_category
# 1       Central
# 2       Central
# 3         South
# 4       Central
# 7       Central

# %% [markdown]
# # 주 카테고리를 지역별(4개)로 나누기

# %%
Highlander = real_data[real_data['model_name']=='Highlander']
Pathfinder = real_data[real_data['model_name']=='Pathfinder']
Pilot = real_data[real_data['model_name']=='Pilot']
Santa_fe = real_data[real_data['model_name']=='Santa_Fe']

hap_table = pd.concat([Highlander, Pathfinder, Pilot, Santa_fe])
print(hap_table.shape)
hap_table['model_name'].unique()
# Out:
# (1408, 13)
# array(['Highlander', 'Pathfinder', 'Pilot', 'Santa_Fe'], dtype=object)

# %%
Central_text = real_data[real_data['City_category']=='Central']['text']
print("내륙 리뷰개수 : " + str(len(Central_text)))
West_text = real_data[real_data['City_category']=='West']['text']
print("서부 리뷰개수 : " + str(len(West_text)))
East_text = real_data[real_data['City_category']=='East']['text']
print("동부 리뷰개수 : " + str(len(East_text)))
South_text = real_data[real_data['City_category']=='South']['text']
print("남부 리뷰개수 : " + str(len(South_text)))
# Out:
# 내륙 리뷰개수 : 2730
# 서부 리뷰개수 : 2605
# 동부 리뷰개수 : 4171
# 남부 리뷰개수 : 4864

# %%
import random
Central_text2 = random.sample(Central_text.tolist(),2605)
West_text2 = random.sample(West_text.tolist(),2605)
East_text2 = random.sample(East_text.tolist(),2605)
South_text2 = random.sample(South_text.tolist(),2605)

# %% [markdown]
# ## 미국 통계청 기준 주 구역 기준

# %%
# test = [
# 'IL', # 일리노이 = 내륙,
# 'SD', # 사우스다코타 = 내륙,
# 'NY', # 뉴욕 = 동부,
# 'TX', # 텍사스 = 남부,
# 'MI', # 미시간 = 내륙,
# 'SC', # 사우스캐로리나 = 남부,
# 'MO', # 미소리 = 내륙,
# 'VA', # 버지니아 = 동부,
# 'PA', # 펜실베니아 = 동부,
# 'OH', # 오하이오 = 중부,
# 'CA', # 캘리보니아 = 서부,
# 'TN', # 테네시 = 남부,
# 'MD', # 메릴랜드 = 동부,
# 'NH', # 뉴햄프셔 = 동부,
# 'FL', # 플로리다 = 남부,
# 'OK', # 오클라호마 = 남부,
# 'WV', # 워싱턴 버지니아 = 남부,
# 'AZ', # 아리조나 = 서부,
# 'GA', # 조지아 = 남부,
# 'WI', # 위스콘신 = 중부,
# 'NJ', # 뉴저지 = 동부,
# 'AL', # 알라바마 = 남부,
# 'KY', # 켄터키 = 남부,
# 'CO', # 콜로라도 = 서부,
# 'IN',# 인디아나 = 중부,
# 'UT', # =서부,
# 'MA', # =동부,
# 'MN', # =중부,
# 'KS', # =중부,
# 'ND', # =중부,
# 'MS', # =남부,
# 'CT', # =동부,
# 'NC', # = 남부,
# 'LA', # =남부
# 'AR', # = 남부
# 'WA', #=서부
# 'NV', #=서부
# 'WY', #=서부
# 'OR', #오레곤 = 서부
# 'ID', #= 서부
# 'AK', #= 알래스카..
# 'NE', #= 중부
# 'MT', #= 서부
# 'DE', #=동부
# 'VT', #=동부
# 'ME', #= 동부
# 'RI', #= 동부
# 'NM', #= 서부
# 'HI' #= 하와이
# 'IA', #= 중부
# ]

# %% [markdown]
# ## 모든 word list Load(날씨, 차종, 파트, 드라이빙)

# %% [markdown]
# ### Weather

# %%
os.chdir('C:\\Users\\kb910\\Google 드라이브\\경배끄10\\인턴\\csv파일')
data = open('weather.txt')

test = [ x for x in data.readlines()]
tab = []
for x in test:
    tab.append(x.split('\n')[0])
    
weather_token = tab[1:]
len(weather_token)
# Out:
# 238

# %% [markdown]
# ### Car categoty

# %%
os.chdir('C:\\Users\\kb910\\Google 드라이브\\경배끄10\\인턴\\csv파일')
data = open('car_category.txt')

test = [ x for x in data.readlines()]
tab = []
for x in test:
    tab.append(x.split('\n')[0])
    
car_category_toekn = tab[1:]
len(car_category_toekn)
# Out:
# 47

# %% [markdown]
# ### Car parts

# %%
os.chdir('C:\\Users\\kb910\\Google 드라이브\\경배끄10\\인턴\\csv파일')
data = open('car_parts.txt')

test = [ x for x in data.readlines()]
tab = []
for x in test:
    tab.append(x.split('\n')[0])
    
car_parts_toekn = tab[1:]
len(car_parts_toekn)
# Out:
# 173

# %% [markdown]
# ### Driving

# %%
os.chdir('C:\\Users\\kb910\\Google 드라이브\\경배끄10\\인턴\\csv파일')
data = open('driving.txt')

test = [ x for x in data.readlines()]
tab = []
for x in test:
    tab.append(x.split('\n')[0])
    
driving_token = tab[1:]
len(driving_token)
# Out:
# 157

# %% [markdown]
# ## 모든 word_list의 합

# %%
all_token = weather_token+driving_token
all_token = list(set(all_token))

# %% [markdown]
# # 4개의 지역별 wordcloud하기

# %% [markdown]
# ## 단어 tokenizing

# %%
from nltk import word_tokenize
from nltk.corpus import stopwords

# %% [markdown]
# ## WordCloud

# %%
from wordcloud import WordCloud, STOPWORDS
from os import path
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import operator

# %% [markdown]
# ## 지역별 차종 count

# %%
def Make_TDM(data):
    
    tdm_table = data
    voca = ['truck','suv','sedan','van','minivan','hatchback','compact','luxury']
    test = [ str(x) for x in tdm_table ] 

    from sklearn.feature_extraction.text import CountVectorizer
    vectorizer = CountVectorizer(vocabulary=voca)
    context = test
    X = vectorizer.fit_transform(context)
    TDM_matrix = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names())

    for column in TDM_matrix.columns:
        TDM_matrix.loc[TDM_matrix[column] != 0, column] = 1

    TDM_matrix.loc[('sum_count')] = [ TDM_matrix[x].sum() for x in TDM_matrix.columns ]
    
    return TDM_matrix

# %%
print((Make_TDM(Central_text2).loc['sum_count']/len(Central_text2))*100)
print((Make_TDM(West_text2).loc['sum_count']/len(West_text2))*100)
print((Make_TDM(East_text2).loc['sum_count']/len(East_text2))*100)
print((Make_TDM(South_text2).loc['sum_count']/len(South_text2))*100)
# Out:
# truck        3.301344
# suv          1.420345
# sedan        0.038388
# van          0.115163
# minivan      0.038388
# hatchback    0.230326
# compact      0.038388
# luxury       0.038388
# Name: sum_count, dtype: float64
# truck        3.109405
# suv          1.612284
# sedan        0.000000
# van          0.191939
# minivan      0.038388
# hatchback    0.268714
# compact      0.000000
# luxury       0.115163
# Name: sum_count, dtype: float64
# truck        3.416507
# suv          1.842610
# sedan        0.038388
# van          0.115163
# minivan      0.115163
# hatchback    0.000000
# compact      0.000000
# luxury       0.115163
# Name: sum_count, dtype: float64
# truck        2.495202
# suv          1.420345
# sedan        0.000000
# van          0.115163
# minivan      0.000000
# hatchback    0.038388
# compact      0.000000
# luxury       0.076775
# Name: sum_count, dtype: float64

# %% [markdown]
# ## Test

# %%
    tokens = [ word_tokenize(word) for word in Central_text2 ]

    wc_sentence =""
    for sentence in tokens:
        for word in sentence:
            if word in car_parts_toekn:
                wc_sentence = wc_sentence+ " " + word

# %%
def make_wordcloud(city, image):
    
    tokens = [ word_tokenize(word) for word in city ]

    wc_sentence =""
    for sentence in tokens:
        for word in sentence:
            if word in all_token:
                wc_sentence = wc_sentence+ " " + word 
                
    os.chdir('C:\\Users\\kb910\\Google 드라이브\\경배끄10\\인턴\\csv파일')
    car_coloring = np.array(Image.open(image+".jpg"))
    wordcloud = WordCloud(max_font_size=40,background_color="white", max_words=100000, mask=car_coloring)
    wordcloud.generate(wc_sentence)

    from wordcloud import ImageColorGenerator
    image_colors = ImageColorGenerator(car_coloring)
    fig, ax = plt.subplots(1, figsize=(10,10))
    plt.imshow(wordcloud, interpolation="bilinear", )
    plt.axis("off")
    plt.savefig(image)
    plt.show()
    
    test = wordcloud.words_
    sorted_x = sorted(test.items(), key=operator.itemgetter(1))
    
    return sorted_x[-40:]

# %%
Central_word= make_wordcloud(Central_text2,'central')

# %%
tab1 = pd.merge(pd.DataFrame(Central_word),pd.DataFrame(West_word),on=0, how='outer')
tab2 = pd.merge(tab1,pd.DataFrame(East_word), on=0, how='outer')
tab3 = pd.merge(tab2,pd.DataFrame(South_word), on=0, how='outer' )
tab3.columns = ['word','Central','West','East','South']
tab3
# Out:
#                  word   Central      West      East     South
# 0             air air  0.126882       NaN       NaN  0.127789
# 1        intersection  0.129032  0.106643       NaN  0.109533
# 2              police  0.131183       NaN  0.120000       NaN
# 3            shoulder  0.131183  0.110140  0.165714  0.115619
# 4         accelerator  0.133333  0.153846       NaN  0.164300
# 5               motor  0.133333       NaN       NaN       NaN
# 6                test  0.133333  0.153846  0.123810  0.115619
# 7             weather  0.133333       NaN       NaN       NaN
# 8       brakes brakes  0.135484  0.110140  0.133333       NaN
# 9         brakes stop  0.135484       NaN       NaN       NaN
# 10         headlights  0.148387       NaN  0.116190       NaN
# 11             closed  0.156989  0.134615  0.139048  0.172414
# 12                oil  0.163441  0.159091  0.118095       NaN
# 13           pressure  0.165591       NaN       NaN       NaN
# 14               cold  0.169892       NaN       NaN       NaN
# 15            oil oil  0.172043  0.145105  0.120000  0.190669
# 16               fuel  0.174194  0.213287       NaN  0.164300
# 17               slow  0.189247  0.192308  0.182857  0.196755
# 18          gas pedal  0.204301  0.208042  0.137143  0.139959
# 19             street  0.225806  0.211538  0.161905  0.188641
# 20         interstate  0.234409       NaN  0.135238  0.255578
# 21             brakes  0.251613  0.318182  0.344762  0.348884
# 22            parking  0.266667  0.265734  0.316190  0.300203
# 23              pedal  0.273118       NaN  0.144762  0.137931
# 24           accident  0.290323  0.272727  0.350476  0.383367
# 25               gear  0.301075  0.286713  0.276190  0.263692
# 26         accelerate  0.322581  0.346154  0.348571  0.346856
# 27             normal  0.352688  0.255245  0.283810  0.239351
# 28                gas  0.378495  0.277972  0.262857  0.263692
# 29      engine engine  0.389247  0.374126  0.350476  0.255578
# 30               park  0.410753  0.403846  0.356190  0.233266
# 31                air  0.412903  0.276224  0.354286  0.446247
# 32            traffic  0.462366  0.480769  0.453333  0.494929
# 33                way  0.488172  0.363636  0.403810  0.423935
# 34            highway  0.516129  0.414336  0.752381  0.608519
# 35             safety  0.632258  0.494755  0.584762  0.604462
# 36            warning  0.711828  0.513986  0.516190  0.653144
# 37               stop  0.821505  0.576923  0.836190  0.876268
# 38             engine  0.974194  1.000000  0.979048  1.000000
# 39                mph  1.000000  0.692308  1.000000  0.892495
# 40             airbag       NaN  0.108392       NaN  0.162272
# 41          stop sign       NaN  0.108392       NaN       NaN
# 42              crash       NaN  0.113636  0.118095  0.144016
# 43              smoke       NaN  0.117133       NaN       NaN
# 44          indicator       NaN  0.120629       NaN       NaN
# 45          stop stop       NaN  0.120629       NaN       NaN
# 46            gas gas       NaN  0.125874       NaN       NaN
# 47             garage       NaN  0.145105  0.116190  0.129817
# 48               hill       NaN  0.169580  0.205714       NaN
# 49            freeway       NaN  0.451049       NaN  0.111562
# 50  accelerator pedal       NaN       NaN  0.114286       NaN
# 51         visibility       NaN       NaN  0.116190       NaN
# 52          tire tire       NaN       NaN  0.120000       NaN
# 53              truck       NaN       NaN  0.140952       NaN
# 54     engine warning       NaN       NaN  0.142857       NaN
# 55            reverse       NaN       NaN  0.228571  0.172414
# 56               auto       NaN       NaN       NaN  0.113590
# 57        mph warning       NaN       NaN       NaN  0.121704
# 58              water       NaN       NaN       NaN  0.125761
# 59            exhaust       NaN       NaN       NaN  0.166329

# %%
for index in range(len(tab3)):
    tab3.loc[index,'mean_value'] = tab3.loc[index].dropna().values[1:].mean()

# %%
tab3
# Out:
#                  word   Central      West      East     South  mean_value
# 0             air air  0.126882       NaN       NaN  0.127789    0.127335
# 1        intersection  0.129032  0.106643       NaN  0.109533    0.115070
# 2              police  0.131183       NaN  0.120000       NaN    0.125591
# 3            shoulder  0.131183  0.110140  0.165714  0.115619    0.130664
# 4         accelerator  0.133333  0.153846       NaN  0.164300    0.150493
# 5               motor  0.133333       NaN       NaN       NaN    0.133333
# 6                test  0.133333  0.153846  0.123810  0.115619    0.131652
# 7             weather  0.133333       NaN       NaN       NaN    0.133333
# 8       brakes brakes  0.135484  0.110140  0.133333       NaN    0.126319
# 9         brakes stop  0.135484       NaN       NaN       NaN    0.135484
# 10         headlights  0.148387       NaN  0.116190       NaN    0.132289
# 11             closed  0.156989  0.134615  0.139048  0.172414    0.150767
# 12                oil  0.163441  0.159091  0.118095       NaN    0.146876
# 13           pressure  0.165591       NaN       NaN       NaN    0.165591
# 14               cold  0.169892       NaN       NaN       NaN    0.169892
# 15            oil oil  0.172043  0.145105  0.120000  0.190669    0.156954
# 16               fuel  0.174194  0.213287       NaN  0.164300    0.183927
# 17               slow  0.189247  0.192308  0.182857  0.196755    0.190292
# 18          gas pedal  0.204301  0.208042  0.137143  0.139959    0.172361
# 19             street  0.225806  0.211538  0.161905  0.188641    0.196973
# 20         interstate  0.234409       NaN  0.135238  0.255578    0.208408
# 21             brakes  0.251613  0.318182  0.344762  0.348884    0.315860
# 22            parking  0.266667  0.265734  0.316190  0.300203    0.287199
# 23              pedal  0.273118       NaN  0.144762  0.137931    0.185270
# 24           accident  0.290323  0.272727  0.350476  0.383367    0.324223
# 25               gear  0.301075  0.286713  0.276190  0.263692    0.281918
# 26         accelerate  0.322581  0.346154  0.348571  0.346856    0.341040
# 27             normal  0.352688  0.255245  0.283810  0.239351    0.282773
# 28                gas  0.378495  0.277972  0.262857  0.263692    0.295754
# 29      engine engine  0.389247  0.374126  0.350476  0.255578    0.342357
# 30               park  0.410753  0.403846  0.356190  0.233266    0.351014
# 31                air  0.412903  0.276224  0.354286  0.446247    0.372415
# 32            traffic  0.462366  0.480769  0.453333  0.494929    0.472849
# 33                way  0.488172  0.363636  0.403810  0.423935    0.419888
# 34            highway  0.516129  0.414336  0.752381  0.608519    0.572841
# 35             safety  0.632258  0.494755  0.584762  0.604462    0.579059
# 36            warning  0.711828  0.513986  0.516190  0.653144    0.598787
# 37               stop  0.821505  0.576923  0.836190  0.876268    0.777722
# 38             engine  0.974194  1.000000  0.979048  1.000000    0.988310
# 39                mph  1.000000  0.692308  1.000000  0.892495    0.896201
# 40             airbag       NaN  0.108392       NaN  0.162272    0.135332
# 41          stop sign       NaN  0.108392       NaN       NaN    0.108392
# 42              crash       NaN  0.113636  0.118095  0.144016    0.125249
# 43              smoke       NaN  0.117133       NaN       NaN    0.117133
# 44          indicator       NaN  0.120629       NaN       NaN    0.120629
# 45          stop stop       NaN  0.120629       NaN       NaN    0.120629
# 46            gas gas       NaN  0.125874       NaN       NaN    0.125874
# 47             garage       NaN  0.145105  0.116190  0.129817    0.130371
# 48               hill       NaN  0.169580  0.205714       NaN    0.187647
# 49            freeway       NaN  0.451049       NaN  0.111562    0.281305
# 50  accelerator pedal       NaN       NaN  0.114286       NaN    0.114286
# 51         visibility       NaN       NaN  0.116190       NaN    0.116190
# 52          tire tire       NaN       NaN  0.120000       NaN    0.120000
# 53              truck       NaN       NaN  0.140952       NaN    0.140952
# 54     engine warning       NaN       NaN  0.142857       NaN    0.142857
# 55            reverse       NaN       NaN  0.228571  0.172414    0.200493
# 56               auto       NaN       NaN       NaN  0.113590    0.113590
# 57        mph warning       NaN       NaN       NaN  0.121704    0.121704
# 58              water       NaN       NaN       NaN  0.125761    0.125761
# 59            exhaust       NaN       NaN       NaN  0.166329    0.166329

# %% [markdown]
# ## 통계적 유의성
# * 0인 애들은 유의미하다.
# * 통계적 거리가 먼 애들(p-value가 큰 애들) 유의미하다.
# * 각 도시별 유의미한 단어들의 평균과 차이를 살핀다.

# %%
shap = pd.concat([pd.DataFrame(Central_word),pd.DataFrame(West_word),pd.DataFrame(East_word),pd.DataFrame(South_word)],axis=1)
shap.columns = ['Central','Central_score','West','West_score','East','East_score','South','South_score']
shap
# Out:
#           Central  Central_score           West  West_score  \
# 0         air air       0.126882   intersection    0.106643
# 1    intersection       0.129032         airbag    0.108392
# 2          police       0.131183      stop sign    0.108392
# 3        shoulder       0.131183       shoulder    0.110140
# 4     accelerator       0.133333  brakes brakes    0.110140
# 5           motor       0.133333          crash    0.113636
# 6            test       0.133333          smoke    0.117133
# 7         weather       0.133333      indicator    0.120629
# 8   brakes brakes       0.135484      stop stop    0.120629
# 9     brakes stop       0.135484        gas gas    0.125874
# 10     headlights       0.148387         closed    0.134615
# 11         closed       0.156989         garage    0.145105
# 12            oil       0.163441        oil oil    0.145105
# 13       pressure       0.165591    accelerator    0.153846
# 14           cold       0.169892           test    0.153846
# 15        oil oil       0.172043            oil    0.159091
# 16           fuel       0.174194           hill    0.169580
# 17           slow       0.189247           slow    0.192308
# 18      gas pedal       0.204301      gas pedal    0.208042
# 19         street       0.225806         street    0.211538
# 20     interstate       0.234409           fuel    0.213287
# 21         brakes       0.251613         normal    0.255245
# 22        parking       0.266667        parking    0.265734
# 23          pedal       0.273118       accident    0.272727
# 24       accident       0.290323            air    0.276224
# 25           gear       0.301075            gas    0.277972
# 26     accelerate       0.322581           gear    0.286713
# 27         normal       0.352688         brakes    0.318182
# 28            gas       0.378495     accelerate    0.346154
# 29  engine engine       0.389247            way    0.363636
# 30           park       0.410753  engine engine    0.374126
# 31            air       0.412903           park    0.403846
# 32        traffic       0.462366        highway    0.414336
# 33            way       0.488172        freeway    0.451049
# 34        highway       0.516129        traffic    0.480769
# 35         safety       0.632258         safety    0.494755
# 36        warning       0.711828        warning    0.513986
# 37           stop       0.821505           stop    0.576923
# 38         engine       0.974194            mph    0.692308
# 39            mph       1.000000         engine    1.000000
#
#                  East  East_score          South  South_score
# 0   accelerator pedal    0.114286   intersection     0.109533
# 1          visibility    0.116190        freeway     0.111562
# 2          headlights    0.116190           auto     0.113590
# 3              garage    0.116190           test     0.115619
# 4                 oil    0.118095       shoulder     0.115619
# 5               crash    0.118095    mph warning     0.121704
# 6              police    0.120000          water     0.125761
# 7             oil oil    0.120000        air air     0.127789
# 8           tire tire    0.120000         garage     0.129817
# 9                test    0.123810          pedal     0.137931
# 10      brakes brakes    0.133333      gas pedal     0.139959
# 11         interstate    0.135238          crash     0.144016
# 12          gas pedal    0.137143         airbag     0.162272
# 13             closed    0.139048           fuel     0.164300
# 14              truck    0.140952    accelerator     0.164300
# 15     engine warning    0.142857        exhaust     0.166329
# 16              pedal    0.144762         closed     0.172414
# 17             street    0.161905        reverse     0.172414
# 18           shoulder    0.165714         street     0.188641
# 19               slow    0.182857        oil oil     0.190669
# 20               hill    0.205714           slow     0.196755
# 21            reverse    0.228571           park     0.233266
# 22                gas    0.262857         normal     0.239351
# 23               gear    0.276190     interstate     0.255578
# 24             normal    0.283810  engine engine     0.255578
# 25            parking    0.316190            gas     0.263692
# 26             brakes    0.344762           gear     0.263692
# 27         accelerate    0.348571        parking     0.300203
# 28           accident    0.350476     accelerate     0.346856
# 29      engine engine    0.350476         brakes     0.348884
# 30                air    0.354286       accident     0.383367
# 31               park    0.356190            way     0.423935
# 32                way    0.403810            air     0.446247
# 33            traffic    0.453333        traffic     0.494929
# 34            warning    0.516190         safety     0.604462
# 35             safety    0.584762        highway     0.608519
# 36            highway    0.752381        warning     0.653144
# 37               stop    0.836190           stop     0.876268
# 38             engine    0.979048            mph     0.892495
# 39                mph    1.000000         engine     1.000000

# %%
West_word = make_wordcloud(West_text2,'west')
# 산악지대
# engine을 중요시

# %%
East_word = make_wordcloud(East_text2,'east')

# %%
South_word = make_wordcloud(South_text2,'south')
# park 랑 거리가 멈
# air 큼
# water

# %%
test=[]
for index in range(40):
    test.append(Central_word[index][0])
    test.append(East_word[index][0])
    test.append(West_word[index][0])
    test.append(South_word[index][0])
    
all_text_list = list(set(test))

# %%
dummy = pd.DataFrame(np.arange(1).reshape(1,1))

# %%
for word_list in [Central_word, West_word, East_word, South_word]:
    check_list = [ word_list[x][0] for x in range(40) ]
    X=[]
    for x in all_text_list:
        if( x in check_list):
            X.append(1)
        else:
            X.append(0)

    call = pd.DataFrame(X, index=all_text_list)
    final = pd.concat([dummy,call], axis=1)
    dummy = final

final.columns = [0,'Central','West','East','South']
final = final.drop(0)
final = final.drop([0],axis=1)
final
# Out:
# C:\Users\kb910\Anaconda3\lib\site-packages\pandas\indexes\range.py:432: RuntimeWarning: '<' not supported between instances of 'int' and 'str', sort order is undefined for incomparable objects
#   return self._int64index.union(other)
#                    Central  West  East  South
# indicator              0.0   1.0   0.0    0.0
# shoulder               1.0   1.0   1.0    1.0
# oil                    1.0   1.0   1.0    0.0
# intersection           1.0   1.0   0.0    1.0
# freeway                0.0   1.0   0.0    1.0
# air                    1.0   1.0   1.0    1.0
# test                   1.0   1.0   1.0    1.0
# hill                   0.0   1.0   1.0    0.0
# brakes stop            1.0   0.0   0.0    0.0
# water                  0.0   0.0   0.0    1.0
# interstate             1.0   0.0   1.0    1.0
# engine                 1.0   1.0   1.0    1.0
# mph                    1.0   1.0   1.0    1.0
# mph warning            0.0   0.0   0.0    1.0
# closed                 1.0   1.0   1.0    1.0
# gas gas                0.0   1.0   0.0    0.0
# visibility             0.0   0.0   1.0    0.0
# slow                   1.0   1.0   1.0    1.0
# headlights             1.0   0.0   1.0    0.0
# truck                  0.0   0.0   1.0    0.0
# stop sign              0.0   1.0   0.0    0.0
# auto                   0.0   0.0   0.0    1.0
# exhaust                0.0   0.0   0.0    1.0
# highway                1.0   1.0   1.0    1.0
# reverse                0.0   0.0   1.0    1.0
# engine engine          1.0   1.0   1.0    1.0
# crash                  0.0   1.0   1.0    1.0
# pedal                  1.0   0.0   1.0    1.0
# street                 1.0   1.0   1.0    1.0
# engine warning         0.0   0.0   1.0    0.0
# motor                  1.0   0.0   0.0    0.0
# cold                   1.0   0.0   0.0    0.0
# oil oil                1.0   1.0   1.0    1.0
# safety                 1.0   1.0   1.0    1.0
# accelerator pedal      0.0   0.0   1.0    0.0
# tire tire              0.0   0.0   1.0    0.0
# fuel                   1.0   1.0   0.0    1.0
# brakes                 1.0   1.0   1.0    1.0
# park                   1.0   1.0   1.0    1.0
# police                 1.0   0.0   1.0    0.0
# parking                1.0   1.0   1.0    1.0
# way                    1.0   1.0   1.0    1.0
# traffic                1.0   1.0   1.0    1.0
# gear                   1.0   1.0   1.0    1.0
# accelerate             1.0   1.0   1.0    1.0
# garage                 0.0   1.0   1.0    1.0
# stop                   1.0   1.0   1.0    1.0
# smoke                  0.0   1.0   0.0    0.0
# accelerator            1.0   1.0   0.0    1.0
# weather                1.0   0.0   0.0    0.0
# accident               1.0   1.0   1.0    1.0
# normal                 1.0   1.0   1.0    1.0
# airbag                 0.0   1.0   0.0    1.0
# brakes brakes          1.0   1.0   1.0    0.0
# warning                1.0   1.0   1.0    1.0
# air air                1.0   0.0   0.0    1.0
# pressure               1.0   0.0   0.0    0.0
# stop stop              0.0   1.0   0.0    0.0
# gas pedal              1.0   1.0   1.0    1.0
# gas                    1.0   1.0   1.0    1.0
